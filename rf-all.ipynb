# %%
from IPython.display import display, Markdown
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from script.helpers import get_data, report_cm

# %%
X, holds, names = get_data()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)

y_pred = pd.Series(classifier.predict(X_test))
y_pred.index = y_test.index

# %%
report_cm('Overall', y_test, y_pred, classifier)
names_test = names[y_test.index]
for name in pd.Categorical(names).categories:
    idx = names_test[names_test == name].index
    report_cm(name, y_test[idx], y_pred[idx], classifier)
# Out:
# # Overall
# accuracy: 0.8936170212765957
# # gregor
# accuracy: 0.9056016597510373
# # jannis
# accuracy: 0.8902536715620828
# # jonas
# accuracy: 0.8916876574307305
# # nikolai
# accuracy: 0.888030888030888
